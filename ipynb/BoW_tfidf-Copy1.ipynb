# %%
from gensim.models import word2vec, fasttext, doc2vec, TfidfModel
from gensim.corpora import Dictionary
import logging
import os
import sys
import gensim
import smart_open

# %%
os.chdir("..")
home_dir = os.getcwd()

# %%
os.chdir("src")
from module import set_data, read_docs
os.chdir(home_dir)

# %%
os.chdir("data")
set_data()

# %%
sentences = read_docs(mode="bow")

dic = Dictionary(sentences)

# %%
dic.doc2bow(sentences[0])
# Out:
# [(0, 5),
#  (1, 1),
#  (2, 16),
#  (3, 1),
#  (4, 1),
#  (5, 1),
#  (6, 7),
#  (7, 2),
#  (8, 4),
#  (9, 1),
#  (10, 1),
#  (11, 5),
#  (12, 2),
#  (13, 1),
#  (14, 1),
#  (15, 1),
#  (16, 1),
#  (17, 1),
#  (18, 7),
#  (19, 1),
#  (20, 1),
#  (21, 1),
#  (22, 1),
#  (23, 1),
#  (24, 1),
#  (25, 2),
#  (26, 1),
#  (27, 1),
#  (28, 1),
#  (29, 1),
#  (30, 2),
#  (31, 1),
#  (32, 1),
#  (33, 1),
#  (34, 3),
#  (35, 4),
#  (36, 18),
#  (37, 14),
#  (38, 4),
#  (39, 4),
#  (40, 2),
#  (41, 1),
#  (42, 1),
#  (43, 1),
#  (44, 1),
#  (45, 15),
#  (46, 2),
#  (47, 1),
#  (48, 5),
#  (49, 7),
#  (50, 1),
#  (51, 1),
#  (52, 1),
#  (53, 1),
#  (54, 6),
#  (55, 2),
#  (56, 1),
#  (57, 6),
#  (58, 9),
#  (59, 1),
#  (60, 1),
#  (61, 1),
#  (62, 1),
#  (63, 2),
#  (64, 1),
#  (65, 9),
#  (66, 1),
#  (67, 2),
#  (68, 4),
#  (69, 1),
#  (70, 34),
#  (71, 15),
#  (72, 1),
#  (73, 1),
#  (74, 1),
#  (75, 2),
#  (76, 2),
#  (77, 1),
#  (78, 1),
#  (79, 1),
#  (80, 10),
#  (81, 1),
#  (82, 3),
#  (83, 1),
#  (84, 1),
#  (85, 4),
#  (86, 1),
#  (87, 1),
#  (88, 2),
#  (89, 1),
#  (90, 1),
#  (91, 1),
#  (92, 3),
#  (93, 5),
#  (94, 8),
#  (95, 4),
#  (96, 1),
#  (97, 1),
#  (98, 1),
#  (99, 1),
#  (100, 2),
#  (101, 1),
#  (102, 3),
#  (103, 1),
#  (104, 1),
#  (105, 1),
#  (106, 2),
#  (107, 1),
#  (108, 4),
#  (109, 2),
#  (110, 1),
#  (111, 1),
#  (112, 2),
#  (113, 1),
#  (114, 5),
#  (115, 3),
#  (116, 1),
#  (117, 1),
#  (118, 3),
#  (119, 2),
#  (120, 2),
#  (121, 2),
#  (122, 1),
#  (123, 1),
#  (124, 4),
#  (125, 1),
#  (126, 1),
#  (127, 8),
#  (128, 1),
#  (129, 1),
#  (130, 17),
#  (131, 6),
#  (132, 1),
#  (133, 1),
#  (134, 1),
#  (135, 1),
#  (136, 4),
#  (137, 1),
#  (138, 2),
#  (139, 6),
#  (140, 1),
#  (141, 3),
#  (142, 2),
#  (143, 2),
#  (144, 1),
#  (145, 1),
#  (146, 1),
#  (147, 2),
#  (148, 1),
#  (149, 1),
#  (150, 1),
#  (151, 1),
#  (152, 2),
#  (153, 2),
#  (154, 2),
#  (155, 1),
#  (156, 1),
#  (157, 1),
#  (158, 1),
#  (159, 1),
#  (160, 6),
#  (161, 1),
#  (162, 1),
#  (163, 1),
#  (164, 2),
#  (165, 1),
#  (166, 1),
#  (167, 2),
#  (168, 1),
#  (169, 1),
#  (170, 3),
#  (171, 5),
#  (172, 1),
#  (173, 2),
#  (174, 1),
#  (175, 3),
#  (176, 1),
#  (177, 1),
#  (178, 2),
#  (179, 1),
#  (180, 1),
#  (181, 1),
#  (182, 6),
#  (183, 11),
#  (184, 1),
#  (185, 2),
#  (186, 1),
#  (187, 1),
#  (188, 1),
#  (189, 2),
#  (190, 1),
#  (191, 1),
#  (192, 1),
#  (193, 6),
#  (194, 2),
#  (195, 3),
#  (196, 1),
#  (197, 3),
#  (198, 1),
#  (199, 2),
#  (200, 1),
#  (201, 1),
#  (202, 3),
#  (203, 5),
#  (204, 3),
#  (205, 1),
#  (206, 3),
#  (207, 2),
#  (208, 1),
#  (209, 1),
#  (210, 2),
#  (211, 1),
#  (212, 3),
#  (213, 1),
#  (214, 1),
#  (215, 1),
#  (216, 1),
#  (217, 3),
#  (218, 1),
#  (219, 2),
#  (220, 2),
#  (221, 1),
#  (222, 1),
#  (223, 1),
#  (224, 1),
#  (225, 2),
#  (226, 1),
#  (227, 1),
#  (228, 1),
#  (229, 3),
#  (230, 1),
#  (231, 2),
#  (232, 2),
#  (233, 1),
#  (234, 1),
#  (235, 13),
#  (236, 13),
#  (237, 1),
#  (238, 2),
#  (239, 1)]
