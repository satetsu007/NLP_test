# %%
from gensim.models import word2vec, fasttext, doc2vec, TfidfModel
from gensim.corpora import Dictionary
from gensim.matutils import corpus2dense
import logging
import os
import sys
import gensim
import smart_open
import numpy as np
import pandas as pd

# %%
os.chdir("..")
home_dir = os.getcwd()
os.chdir("src")

# %%
from module import set_data, bow_read_docs
from train import bow, tfidf
from test import load_model
os.chdir(home_dir)

# %%
os.getcwd()
# Out:
# '/Users/satetsu/program/python/NLP'

# %% [markdown]
# ## Doc2Vec

# %%
os.chdir(home_dir)
model = load_model("doc2vec", "doc2vec_1.model")
os.chdir("data")
file_names = os.listdir("tmp_file")
doc_matrix = np.array([model.docvecs[i] for i, _ in enumerate(file_names)])

# 文章ベクトル
doc_df = pd.DataFrame(doc_matrix)
doc_df.index = file_names
# 単語ベクトル
doc2vec_df = pd.DataFrame(model.wv.vectors)
doc2vec_df.index = model.wv.vocab.keys()
# Out:
# load model.

# %%
doc_df.head()
# Out:
#                         0         1         2         3         4         5   \
# m:A_1_wakati.txt -0.004399 -0.003293  0.005095  0.002972 -0.001343  0.001610
# m:A_2_wakati.txt  0.002052 -0.003202  0.001758 -0.000865 -0.005103  0.002033
# m:B_1_wakati.txt  0.002332  0.004859  0.005176  0.000948 -0.003426 -0.002673
# m:B_2_wakati.txt -0.001437 -0.004386  0.005290 -0.001166 -0.001039 -0.002368
# m:C_1_wakati.txt -0.001376 -0.000957 -0.000920  0.001847 -0.001486  0.003397
#
#                         6         7         8         9     ...           90  \
# m:A_1_wakati.txt -0.003136 -0.005095 -0.001655  0.002759    ...    -0.004402
# m:A_2_wakati.txt -0.001769 -0.002915 -0.000305  0.002708    ...     0.003729
# m:B_1_wakati.txt -0.004335  0.001107  0.002182 -0.000334    ...     0.003982
# m:B_2_wakati.txt  0.000992  0.004748  0.003490 -0.001636    ...    -0.000366
# m:C_1_wakati.txt  0.000770 -0.001926 -0.004909  0.004969    ...     0.000591
#
# ...

# %%
doc2vec_df.head()
# Out:
#            0         1         2         3         4         5         6   \
# 商船   0.001438  0.004325  0.004920  0.000382  0.002226 -0.002002  0.003418
# 三井   0.002993  0.003313  0.003973  0.000766  0.002224 -0.003841 -0.003455
# 新規   0.003107  0.001016  0.000275 -0.002067  0.004402 -0.002779  0.000094
# ドライ  0.001528 -0.002496  0.005812  0.004926  0.000020  0.000339  0.002926
# 市況   0.000992  0.000541 -0.001916 -0.003626 -0.004275  0.000382 -0.004000
#
#            7         8         9     ...           90        91        92  \
# 商船   0.000741  0.002489  0.000481    ...     0.001545  0.002183 -0.000267
# 三井   0.000370 -0.004088  0.002548    ...    -0.000744 -0.002592 -0.004334
# 新規  -0.000562 -0.000285  0.000793    ...    -0.000935  0.003455 -0.002742
# ドライ -0.003206 -0.003925  0.001821    ...     0.000278  0.000649  0.000806
# 市況  -0.003530  0.002539 -0.003910    ...    -0.001301 -0.004350 -0.002915
#
#            93        94        95        96        97        98        99
# ...

# %% [markdown]
# ## Word2Vec

# %%
os.chdir(home_dir)
model = load_model("word2vec", "word2vec_1.model")
file_names = os.listdir("data/tmp_file")

# 単語ベクトル
word2vec_df = pd.DataFrame(model.wv.vectors)
word2vec_df.index = model.wv.vocab.keys()
# Out:
# load model.

# %%
word2vec_df.head()
# Out:
#            0         1         2         3         4         5         6   \
# 商船   0.003884  0.005460  0.011329  0.003914 -0.007435  0.003889  0.000977
# 三井   0.002900  0.007174  0.007288  0.001551  0.000479 -0.001577  0.002749
# *   -0.000619  0.008191 -0.000464  0.000186 -0.002323  0.002439 -0.005487
# 新規   0.004465  0.006187  0.006664  0.002363  0.000253 -0.003273 -0.004324
# ドライ  0.002617 -0.001988  0.004170  0.005285 -0.003889  0.005363 -0.000198
#
#            7         8         9     ...           90        91        92  \
# 商船  -0.006568  0.001161  0.007641    ...     0.002542  0.002423  0.002861
# 三井   0.000329  0.003635  0.002292    ...     0.001382  0.003090  0.000261
# *    0.002008  0.005760  0.007316    ...    -0.003880 -0.003874  0.004438
# 新規  -0.000314 -0.003118  0.004497    ...    -0.000820 -0.001888 -0.004182
# ドライ -0.005121 -0.003722 -0.001215    ...     0.001060 -0.004054  0.002661
#
#            93        94        95        96        97        98        99
# ...

# %% [markdown]
# ## fasttext

# %%
os.chdir(home_dir)
model = load_model("fasttext", "fasttext_1.model")
os.chdir("data")
file_names = os.listdir("tmp_file")

# 単語ベクトル
fasttext_df = pd.DataFrame(model.wv.vectors)
fasttext_df.index = model.wv.vocab.keys()
# Out:
# load model.

# %%
fasttext_df.head()
# Out:
#            0         1         2         3         4         5         6   \
# 商船  -0.001756  0.012983  0.000831 -0.003695 -0.010197 -0.005745 -0.005141
# 三井  -0.001034  0.000763  0.005319 -0.001690  0.001057  0.003071 -0.002664
# *    0.008786  0.004645  0.005183  0.001654 -0.006411 -0.004357 -0.000703
# 新規   0.002378  0.005991  0.006413  0.005231 -0.002669 -0.000095 -0.000655
# ドライ  0.006899  0.000657 -0.002764  0.002264 -0.004143  0.008942 -0.003761
#
#            7         8         9     ...           90        91        92  \
# 商船   0.001171 -0.000501  0.001692    ...    -0.006383  0.012650  0.001805
# 三井   0.005284  0.000675  0.003786    ...    -0.006341 -0.002403  0.000564
# *    0.000488  0.007726  0.004241    ...    -0.004839  0.005326  0.001226
# 新規  -0.000674  0.000607 -0.002165    ...    -0.005467  0.002227 -0.002515
# ドライ -0.002437 -0.007191  0.001799    ...     0.004110  0.009432  0.003015
#
#            93        94        95        96        97        98        99
# ...

# %%
# 変数 abc があるかどうかをチェック
try:
    df2
except NameError:
    print("df2はない")
    # なかった場合の処理
# Out:
# df2はない
